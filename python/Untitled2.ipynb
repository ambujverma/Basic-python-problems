# %%
import pandas as pd
df = pd.read_csv("50-contacts.csv")

# %%
df=df.head(5)
df
# Out:
#        James      Butt       Benton, John B Jr    6649 N Blue Gum St  \
# 0  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 1        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 2      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 3    Donette    Foller     Printing Dimensions          34 Center St
# 4     Simona   Morasca     Chapman, Ross E Esq          3 Mcauley Dr
#
#   New Orleans     Orleans  LA  70116  504-621-8927  504-845-1427  \
# 0    Brighton  Livingston  MI  48116  810-292-9388  810-374-9840
# 1  Bridgeport  Gloucester  NJ   8014  856-636-8749  856-264-4130
# 2   Anchorage   Anchorage  AK  99501  907-385-4412  907-921-2010
# 3    Hamilton      Butler  OH  45011  513-570-1893  513-549-4561
# 4     Ashland     Ashland  OH  44805  419-503-2484  419-800-6759
#
#                  jbutt@gmail.com
# 0  josephine_darakjy@darakjy.org
# 1                 art@venere.org
# 2          lpaprocki@hotmail.com
# ...
